# %% [markdown]
# # Television Brands Ecommerce Data Analysis

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
tb=pd.read_csv(r'C:\Users\femif\Downloads\final_data.csv\TV_Final.xls')
tb
# Out:
#        Brand     Resolution  Size   Selling Price  Original Price  \
# 0    TOSHIBA   Ultra HD LED     55          37999           54990
# 1       TCL   QLED Ultra HD     55          52999          129990
# 2    realme          HD LED     32          13999           17999
# 3        Mi          HD LED     32          14999           19999
# 4    realme          HD LED     32          12999           21999
# ..       ...            ...    ...            ...             ...
# 907    SONY     Full HD LED     43          44999           57900
# 908    SONY     Full HD LED     40          41499           51900
# 909    SONY    Ultra HD LED     65         149990          184990
# 910    SONY          HD LED     32          32900           32900
# 911    SONY     Full HD LED     43          56900           56900
#
#     Operating System  Rating
# 0              VIDAA     4.3
# 1            Android     4.4
# 2            Android     4.3
# 3            Android     4.4
# ...

# %% [markdown]
# #### 1.Demand for different types of televisions and Number of Players in the market

# %%
tb.head()
# Out:
#      Brand     Resolution  Size   Selling Price  Original Price  \
# 0  TOSHIBA   Ultra HD LED     55          37999           54990
# 1     TCL   QLED Ultra HD     55          52999          129990
# 2  realme          HD LED     32          13999           17999
# 3      Mi          HD LED     32          14999           19999
# 4  realme          HD LED     32          12999           21999
#
#   Operating System  Rating
# 0            VIDAA     4.3
# 1          Android     4.4
# 2          Android     4.3
# 3          Android     4.4
# 4          Android     4.3

# %%
tb.columns
# Out:
# Index(['Brand', 'Resolution', 'Size ', 'Selling Price', 'Original Price',
#        'Operating System', 'Rating'],
#       dtype='object')

# %%
tb['Brand'].head()
# Out:
# 0    TOSHIBA
# 1       TCL
# 2    realme
# 3        Mi
# 4    realme
# Name: Brand, dtype: object

# %%
tb['Operating System'].value_counts()
# Out:
# Android      474
# Tizen        145
# Linux        127
# WebOS        109
# HomeOS        28
# VIDAA         13
# FireTV OS      5
# Name: Operating System, dtype: int64

# %%
tb['Resolution'].value_counts()
# Out:
# Ultra HD LED     399
# HD LED           229
# Full HD LED      220
# QLED Ultra HD     60
# HD Plasma          4
# Name: Resolution, dtype: int64

# %% [markdown]
# Ultra HD LED  is the most in demand television

# %%
plt.figure(figsize=(12, 6))
sns.barplot(x='Resolution', y='Rating', data=tb)
plt.title('Television ratings')
plt.xlabel('Resolution')
plt.ylabel('Rating')
plt.xticks(rotation=45, ha='right')
plt.legend()
plt.show()
# Out:
# C:\Users\femif\anaconda3\Lib\site-packages\seaborn\algorithms.py:98: RuntimeWarning: Mean of empty slice
#   boot_dist.append(f(*sample, **func_kwargs))
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
plt.figure(figsize = (15,10))
sns.set_style('white')
sns.countplot(y="Brand", hue="Resolution", data=tb,width=3)
plt.title('Brands and Resolution')
plt.grid(True)

# %%
tb[['Brand','Resolution']].value_counts().reset_index()
# Out:
#        Brand     Resolution   0
# 0        LG    Ultra HD LED  79
# 1    SAMSUNG   Ultra HD LED  55
# 2      SONY    Ultra HD LED  38
# 3    SAMSUNG  QLED Ultra HD  36
# 4    SAMSUNG    Full HD LED  33
# ..       ...            ...  ..
# 155   Nokia   QLED Ultra HD   1
# 156  OnePlus         HD LED   1
# 157  Sansui   QLED Ultra HD   1
# 158   Sharp    Ultra HD LED   1
# 159   Maser          HD LED   1
#
# [160 rows x 3 columns]

# %% [markdown]
# #### 2.Which are the top 5 brands for television?

# %%
tb['Brand'].value_counts().head(5)
# Out:
# SAMSUNG      140
# LG           122
# SONY          62
# TCL           44
# Panasonic     30
# Name: Brand, dtype: int64

# %%
tb['Brand'].value_counts().head(5).plot(kind='bar')
# Out:
# <Axes: >

# %% [markdown]
# ##### 3.Which brand has the highest number of products i.e. television

# %%
tb['Brand'].value_counts().head()
# Out:
# SAMSUNG      140
# LG           122
# SONY          62
# TCL           44
# Panasonic     30
# Name: Brand, dtype: int64

# %%
tb['Brand'].value_counts().head().max()
# Out:
# 140

# %% [markdown]
# samsung brand has the most products

# %% [markdown]
# #### 4.Are televisions with higher ratings more expensive

# %%
plt.figure(figsize=(12, 6))
sns.barplot(x='Resolution', y='Rating', data=tb)
plt.title('Television ratings')
plt.xlabel('Resolution')
plt.ylabel('Rating')
plt.xticks(rotation=45, ha='right')
plt.legend()
plt.show()
# Out:
# C:\Users\femif\anaconda3\Lib\site-packages\seaborn\algorithms.py:98: RuntimeWarning: Mean of empty slice
#   boot_dist.append(f(*sample, **func_kwargs))
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
tb.groupby('Resolution')['Rating','Selling Price'].sum()
# Out:
# C:\Users\femif\AppData\Local\Temp\ipykernel_4348\572604643.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   tb.groupby('Resolution')['Rating','Selling Price'].sum()
#                Rating  Selling Price
# Resolution
# Full HD LED     768.0       11598405
# HD LED          738.2        3542930
# HD Plasma         7.3         228980
# QLED Ultra HD   156.1        7525047
# Ultra HD LED   1260.4       31239687

# %% [markdown]
# we can see televisions with higher ratings more expensive

# %% [markdown]
# ##### 5.Average Selling Price by Brand

# %%
plt.figure(figsize=(8,5))
sns.barplot(x=df['Operating System'], y=df['Selling Price'])
plt.show()

# %%
tb.groupby('Brand')['Selling Price'].sum().sort_values(ascending=False).reset_index()
# Out:
#                Brand  Selling Price
# 0            SAMSUNG       14897292
# 1                LG        11823557
# 2              SONY         5539256
# 3               TCL         2455126
# 4          Panasonic        1604819
# 5             Sharp         1197376
# 6                 Vu        1072947
# 7    iFFALCON by TCL        1030454
# 8            Hisense         897954
# 9             Lloyd          751560
# 10           Samsung         729780
# 11           Sansui          678095
# 12          Micromax         671739
# 13            Haier          659092
# 14               Mi          584954
# 15           PHILIPS         579935
# 16          MOTOROLA         575985
# 17           TOSHIBA         505087
# 18           Thomson         454482
# 19            Nokia          427489
# 20           OnePlus         426382
# 21            IMPEX          374652
# 22             Onida         356486
# 23         Blaupunkt         355685
# 24            KODAK          354976
# ...

# %%
tb.groupby('Brand')['Selling Price'].mean().sort_values(ascending=False)
# Out:
# Brand
# Sharp               149672.000000
# Samsung             121630.000000
# SAMSUNG             106409.228571
# LG                   96914.401639
# Hisense              89795.400000
# SONY                 89342.838710
# TCL                  55798.318182
# iFFALCON by TCL      54234.421053
# Panasonic            53493.966667
# Akai                 52002.833333
# OnePlus              47375.777778
# Vu                   46649.869565
# Compaq               45999.000000
# Sanyo                45499.000000
# Weston               43390.000000
# Oxygen               40326.333333
# Nokia                38862.636364
# TOSHIBA              38852.846154
# MOTOROLA             38399.000000
# Sansui               37671.944444
# Haier                36616.222222
# AISEN                35462.500000
# BPL                  34617.250000
# Onix                 34216.250000
# Lloyd                34161.818182
# PHILIPS              34113.823529
# JVC                  32496.333333
# ...

# %% [markdown]
# ####  Data Exploration

# %% [markdown]
# Identifying data quality issues such as missing values, duplicates, and outliers ensures
# that subsequent analyses are based on clean and reliable data.

# %%
tb.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 912 entries, 0 to 911
# Data columns (total 7 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Brand             912 non-null    object
#  1   Resolution        912 non-null    object
#  2   Size              912 non-null    int64
#  3   Selling Price     912 non-null    int64
#  4   Original Price    912 non-null    int64
#  5   Operating System  901 non-null    object
#  6   Rating            692 non-null    float64
# dtypes: float64(1), int64(3), object(3)
# memory usage: 50.0+ KB

# %%
# Check for missing values 
tb.isnull().sum()
# Out:
# Brand                 0
# Resolution            0
# Size                  0
# Selling Price         0
# Original Price        0
# Operating System     11
# Rating              220
# dtype: int64

# %%
#Check for duplicates values
duplicates = tb.duplicated()
duplicates.sum()
# Out:
# 30

# %%
# Drop rows with missing values
tb.dropna()
# Out:
#        Brand     Resolution  Size   Selling Price  Original Price  \
# 0    TOSHIBA   Ultra HD LED     55          37999           54990
# 1       TCL   QLED Ultra HD     55          52999          129990
# 2    realme          HD LED     32          13999           17999
# 3        Mi          HD LED     32          14999           19999
# 4    realme          HD LED     32          12999           21999
# ..       ...            ...    ...            ...             ...
# 907    SONY     Full HD LED     43          44999           57900
# 908    SONY     Full HD LED     40          41499           51900
# 909    SONY    Ultra HD LED     65         149990          184990
# 910    SONY          HD LED     32          32900           32900
# 911    SONY     Full HD LED     43          56900           56900
#
#     Operating System  Rating
# 0              VIDAA     4.3
# 1            Android     4.4
# 2            Android     4.3
# 3            Android     4.4
# ...

# %%
tb.describe()
# Out:
#             Size   Selling Price  Original Price      Rating
# count  912.000000     912.000000      912.000000  692.000000
# mean    45.942982   59358.606360    81975.213816    4.234104
# std     12.316492   65866.677856    84823.568826    0.366694
# min     17.000000    4849.000000     6999.000000    2.000000
# 25%     32.000000   19797.500000    28990.000000    4.100000
# 50%     43.000000   36990.000000    52900.000000    4.300000
# 75%     55.000000   67064.250000    99900.000000    4.400000
# max     85.000000  499990.000000   549990.000000    5.000000

# %% [markdown]
# ####  Visualization

# %% [markdown]
# Visualizing the distribution of key variables helps in understanding the data's overall
# patterns, making it easier to identify trends or anoma lies.

# %% [markdown]
# ###### Brand Analysis

# %% [markdown]
# Analyzing the distribution of products across different brands provides insights into
# market share and popularity, helping businesses understand their competitive landscap
